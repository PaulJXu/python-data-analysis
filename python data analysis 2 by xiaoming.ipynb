# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("adultTest.csv")

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship   race     sex  \
# 0        Never-married        Adm-clerical   Not-in-family  White    Male
# 1   Married-civ-spouse     Exec-managerial         Husband  White    Male
# 2             Divorced   Handlers-cleaners   Not-in-family  White    Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband  Black    Male
# 4   Married-civ-spouse      Prof-specialty            Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df1 = df.set_index(["race","sex"])

# %%
df1.head()
# Out:
#               age          workclass  fnlwgt   education  education-num  \
# race  sex
# White Male     39          State-gov   77516   Bachelors             13
#       Male     50   Self-emp-not-inc   83311   Bachelors             13
#       Male     38            Private  215646     HS-grad              9
# Black Male     53            Private  234721        11th              7
#       Female   28            Private  338409   Bachelors             13
#
#                    marital-status          occupation    relationship  \
# race  sex
# White Male          Never-married        Adm-clerical   Not-in-family
#       Male     Married-civ-spouse     Exec-managerial         Husband
#       Male               Divorced   Handlers-cleaners   Not-in-family
# Black Male     Married-civ-spouse   Handlers-cleaners         Husband
#       Female   Married-civ-spouse      Prof-specialty            Wife
#
#               capital-gain  capital-loss  hours-per-week  native-country  \
# race  sex
# ...

# %%
df1.reset_index(['race','sex'])
# Out:
#                      race     sex  age          workclass  fnlwgt  \
# 0                   White    Male   39          State-gov   77516
# 1                   White    Male   50   Self-emp-not-inc   83311
# 2                   White    Male   38            Private  215646
# 3                   Black    Male   53            Private  234721
# 4                   Black  Female   28            Private  338409
# 5                   White  Female   37            Private  284582
# 6                   Black  Female   49            Private  160187
# 7                   White    Male   52   Self-emp-not-inc  209642
# 8                   White  Female   31            Private   45781
# 9                   White    Male   42            Private  159449
# 10                  Black    Male   37            Private  280464
# 11     Asian-Pac-Islander    Male   30          State-gov  141297
# 12                  White  Female   23            Private  122272
# ...

# %%
df1.head()
# Out:
#               age          workclass  fnlwgt   education  education-num  \
# race  sex
# White Male     39          State-gov   77516   Bachelors             13
#       Male     50   Self-emp-not-inc   83311   Bachelors             13
#       Male     38            Private  215646     HS-grad              9
# Black Male     53            Private  234721        11th              7
#       Female   28            Private  338409   Bachelors             13
#
#                    marital-status          occupation    relationship  \
# race  sex
# White Male          Never-married        Adm-clerical   Not-in-family
#       Male     Married-civ-spouse     Exec-managerial         Husband
#       Male               Divorced   Handlers-cleaners   Not-in-family
# Black Male     Married-civ-spouse   Handlers-cleaners         Husband
#       Female   Married-civ-spouse      Prof-specialty            Wife
#
#               capital-gain  capital-loss  hours-per-week  native-country  \
# race  sex
# ...

# %%
df1.loc[("White","Male"),'age']
# Out:
# D:\学习\A\lib\site-packages\pandas\core\indexing.py:1294: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
# race   sex
# White  Male    39
#        Male    50
#        Male    38
#        Male    52
#        Male    42
#        Male    25
#        Male    32
#        Male    38
#        Male    40
#        Male    43
#        Male    56
#        Male    19
#        Male    39
#        Male    49
#        Male    23
#        Male    45
#        Male    30
#        Male    48
#        Male    21
#        Male    31
#        Male    48
#        Male    31
#        Male    53
#        Male    24
#        Male    25
#        Male    53
#        Male    41
#        Male    29
#        Male    50
#        Male    47
#                ..
#        Male    26
#        Male    18
#        Male    57
#        Male    34
#        Male    71
#        Male    35
#        Male    47
#        Male    38
#        Male    50
#        Male    39
# ...

# %%
df2 = df1.sort_index()

# %%
df2.loc[("White","Male"),"age"]
# Out:
# race   sex
# White  Male    39
#        Male    50
#        Male    38
#        Male    52
#        Male    42
#        Male    25
#        Male    32
#        Male    38
#        Male    40
#        Male    43
#        Male    56
#        Male    19
#        Male    39
#        Male    49
#        Male    23
#        Male    45
#        Male    30
#        Male    48
#        Male    21
#        Male    31
#        Male    48
#        Male    31
#        Male    53
#        Male    24
#        Male    25
#        Male    53
#        Male    41
#        Male    29
#        Male    50
#        Male    47
#                ..
#        Male    26
#        Male    18
#        Male    57
#        Male    34
#        Male    71
#        Male    35
#        Male    47
#        Male    38
#        Male    50
#        Male    39
#        Male    20
#        Male    66
#        Male    36
#        Male    57
#        Male    46
#        Male    58
#        Male    30
#        Male    32
# ...

# %%
df2.loc[(["White","Black"],["Male"]),"age"]
# Out:
# race   sex
# Black  Male    53
#        Male    37
#        Male    32
#        Male    35
#        Male    20
#        Male    22
#        Male    57
#        Male    32
#        Male    49
#        Male    30
#        Male    19
#        Male    71
#        Male    42
#        Male    21
#        Male    34
#        Male    44
#        Male    30
#        Male    34
#        Male    41
#        Male    36
#        Male    44
#        Male    37
#        Male    90
#        Male    54
#        Male    35
#        Male    43
#        Male    41
#        Male    19
#        Male    45
#        Male    45
#                ..
# White  Male    26
#        Male    18
#        Male    57
#        Male    34
#        Male    71
#        Male    35
#        Male    47
#        Male    38
#        Male    50
#        Male    39
#        Male    20
#        Male    66
#        Male    36
#        Male    57
#        Male    46
#        Male    58
#        Male    30
#        Male    32
# ...

# %% [markdown]
# ## 多重索引之前请必须对索引进行排序

# %%
# slice 
df3 = df2.set_index("age",append = True)

# %%
df3.sort_index(inplace=True)

# %%
df3.loc[(slice("Black","White"),["Female"],slice(17,30)),]
# Out:
#                           workclass  fnlwgt      education  education-num  \
# race  sex    age
# Black Female 17             Private  295488           11th              7
#              17                   ?  659273           11th              7
#              17             Private  117549           10th              6
#              17             Private   75333           10th              6
#              17             Private  222618           11th              7
#              17             Private   19752           11th              7
#              17             Private  143791           10th              6
#              17                   ?   48751           11th              7
#              17             Private  317702            9th              5
#              17             Private  225507           11th              7
#              17         Federal-gov   99893           11th              7
# ...

# %%
df3.xs(('Black','Male'),level = ('race','sex'))
# Out:
#              workclass  fnlwgt      education  education-num  \
# age
# 17           Local-gov   32124            9th              5
# 17                   ?  127003            9th              5
# 17             Private  221403           12th              8
# 17             Private  154398           11th              7
# 17             Private  234780        HS-grad              9
# 17             Private  126779           11th              7
# 17             Private  250541           10th              6
# 17        Self-emp-inc  325171           10th              6
# 17             Private  133449            9th              5
# 17                   ?  148769        HS-grad              9
# 17             Private  142457           11th              7
# 17             Private  225211            9th              5
# 17           Local-gov  173497           11th              7
# 17             Private  321880           10th              6
# ...

# %%
df3.xs(('Black','Male'),level = (0,1))
# Out:
#              workclass  fnlwgt      education  education-num  \
# age
# 17           Local-gov   32124            9th              5
# 17                   ?  127003            9th              5
# 17             Private  221403           12th              8
# 17             Private  154398           11th              7
# 17             Private  234780        HS-grad              9
# 17             Private  126779           11th              7
# 17             Private  250541           10th              6
# 17        Self-emp-inc  325171           10th              6
# 17             Private  133449            9th              5
# 17                   ?  148769        HS-grad              9
# 17             Private  142457           11th              7
# 17             Private  225211            9th              5
# 17           Local-gov  173497           11th              7
# 17             Private  321880           10th              6
# ...

# %%
grouped = df.groupby(["race","sex"])

# %%
df1.groupby(level = [0,1])

# %%
grouped.size()
# Out:
# race                sex
# Amer-Indian-Eskimo  Female      119
#                     Male        192
# Asian-Pac-Islander  Female      346
#                     Male        693
# Black               Female     1555
#                     Male       1569
# Other               Female      109
#                     Male        162
# White               Female     8642
#                     Male      19174
# dtype: int64

# %%
grouped['age'].mean()
# Out:
# race                sex
# Amer-Indian-Eskimo  Female    37.117647
#                     Male      37.208333
# Asian-Pac-Islander  Female    35.089595
#                     Male      39.073593
# Black               Female    37.854019
#                     Male      37.682600
# Other               Female    31.678899
#                     Male      34.654321
# White               Female    36.811618
#                     Male      39.652498
# Name: age, dtype: float64

# %%
grouped["fnlwgt"].sum()
# Out:
# race                sex
# Amer-Indian-Eskimo  Female      13441137
#                     Male        24137350
# Asian-Pac-Islander  Female      51018418
#                     Male       115159875
# Black               Female     331170508
#                     Male       381142492
# Other               Female      18804641
#                     Male        34616015
# White               Female    1586238814
#                     Male      3623644142
# Name: fnlwgt, dtype: int64

# %%
grouped.agg({"age":np.sum,"fnlwgt":np.mean,.....}) # 一定要会
# Out:
#                            fnlwgt     age
# race               sex
# Amer-Indian-Eskimo Female  112950    4417
#                    Male    125715    7144
# Asian-Pac-Islander Female  147452   12141
#                    Male    166175   27078
# Black              Female  212971   58863
#                    Male    242920   59124
# Other              Female  172519    3453
#                    Male    213679    5614
# White              Female  183549  318126
#                    Male    188987  760297

# %%
grouped['age'].agg([np.sum,np.mean,np.std])
# Out:
#                               sum       mean        std
# race               sex
# Amer-Indian-Eskimo Female    4417  37.117647  13.114991
#                    Male      7144  37.208333  12.049563
# Asian-Pac-Islander Female   12141  35.089595  12.300845
#                    Male     27078  39.073593  12.883944
# Black              Female   58863  37.854019  12.637197
#                    Male     59124  37.682600  12.882612
# Other              Female    3453  31.678899  11.631599
#                    Male      5614  34.654321  11.355531
# White              Female  318126  36.811618  14.329093
#                    Male    760297  39.652498  13.436029

# %%
grouped.agg([np.sum,np.mean,np.std])
# Out:
#                               age                            fnlwgt          \
#                               sum       mean        std         sum    mean
# race               sex
# Amer-Indian-Eskimo Female    4417  37.117647  13.114991    13441137  112950
#                    Male      7144  37.208333  12.049563    24137350  125715
# Asian-Pac-Islander Female   12141  35.089595  12.300845    51018418  147452
#                    Male     27078  39.073593  12.883944   115159875  166175
# Black              Female   58863  37.854019  12.637197   331170508  212971
#                    Male     59124  37.682600  12.882612   381142492  242920
# Other              Female    3453  31.678899  11.631599    18804641  172519
#                    Male      5614  34.654321  11.355531    34616015  213679
# White              Female  318126  36.811618  14.329093  1586238814  183549
#                    Male    760297  39.652498  13.436029  3623644142  188987
#
# ...

# %%
grouped['age'].agg({"求平均数":np.mean,"求和":np.sum})
#grouped.agg({"age":np.sum,"fnlwgt":np.mean})
# Out:
#                                 求平均数      求和
# race               sex
# Amer-Indian-Eskimo Female  37.117647    4417
#                    Male    37.208333    7144
# Asian-Pac-Islander Female  35.089595   12141
#                    Male    39.073593   27078
# Black              Female  37.854019   58863
#                    Male    37.682600   59124
# Other              Female  31.678899    3453
#                    Male    34.654321    5614
# White              Female  36.811618  318126
#                    Male    39.652498  760297

# %%
for name,group in grouped:
    print (name)
    print(len(group))
# Out:
# ('Amer-Indian-Eskimo', 'Female')
# 119
# ('Amer-Indian-Eskimo', 'Male')
# 192
# ('Asian-Pac-Islander', 'Female')
# 346
# ('Asian-Pac-Islander', 'Male')
# 693
# ('Black', 'Female')
# 1555
# ('Black', 'Male')
# 1569
# ('Other', 'Female')
# 109
# ('Other', 'Male')
# 162
# ('White', 'Female')
# 8642
# ('White', 'Male')
# 19174

# %%
grouped.size()
# Out:
# race                sex
# Amer-Indian-Eskimo  Female      119
#                     Male        192
# Asian-Pac-Islander  Female      346
#                     Male        693
# Black               Female     1555
#                     Male       1569
# Other               Female      109
#                     Male        162
# White               Female     8642
#                     Male      19174
# dtype: int64

# %%
zscore = lambda s : (s - s.mean()) / s.std()

# %%
grouped.transform(lambda s : (s - s.mean()) / s.std())
# Out:
#             age    fnlwgt  education-num  capital-gain  capital-loss  \
# 0     -0.048563 -1.074790       1.077176      0.095386     -0.235540
# 1      0.770131 -1.018915       1.077176     -0.162111     -0.235540
# 2     -0.122990  0.257038      -0.428585     -0.162111     -0.235540
# 3      1.188998 -0.061125      -1.016937     -0.141564     -0.202671
# 4     -0.779763  1.140640       1.562704     -0.097237     -0.151959
# 5      0.013147  0.993331       1.635064     -0.120427     -0.185594
# 6      0.881998 -0.479983      -2.060789     -0.097237     -0.151959
# 7      0.918984  0.199149      -0.428585     -0.162111     -0.235540
# 8     -0.405582 -1.354523       1.635064      2.836451     -0.185594
# 9      0.174717 -0.284805       1.077176      0.451191     -0.235540
# 10    -0.052986  0.279869       0.242064     -0.141564     -0.202671
# 11    -0.704256 -0.280949       0.631760     -0.166961     -0.254534
# 12    -0.963886 -0.602476       1.212788     -0.120427     -0.185594
# ...

# %%
grouped.size()
# Out:
# race                sex
# Amer-Indian-Eskimo  Female      119
#                     Male        192
# Asian-Pac-Islander  Female      346
#                     Male        693
# Black               Female     1555
#                     Male       1569
# Other               Female      109
#                     Male        162
# White               Female     8642
#                     Male      19174
# dtype: int64

# %%
df5 = grouped.filter(lambda s : len(s)>= 1000)

# %%
grouped1 = df5.groupby(['race','sex'])

# %%
grouped1.size()
# Out:
# race   sex
# Black  Female     1555
#        Male       1569
# White  Female     8642
#        Male      19174
# dtype: int64

# %%
# 筛选出年龄大于32的小组数据

# %%
grouped.filter(lambda s : s['age'].mean() >= 35)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
grouped.groups
# Out:
# {('Amer-Indian-Eskimo', 'Female'): [212,
#   226,
#   516,
#   596,
#   940,
#   1715,
#   2036,
#   2313,
#   2383,
#   2610,
#   2720,
#   2993,
#   3589,
#   3598,
#   3605,
#   3729,
#   3821,
#   4112,
#   4169,
#   4348,
#   4948,
#   5127,
#   5214,
#   5464,
#   5481,
#   5624,
#   5775,
#   5846,
#   6228,
#   6391,
#   6902,
#   6930,
#   7042,
#   7078,
#   7519,
#   7656,
#   8089,
#   8155,
#   8330,
#   8670,
#   9226,
#   9634,
#   9825,
#   9965,
#   10012,
#   10152,
#   11263,
#   12220,
#   12553,
#   13828,
#   14360,
#   14363,
#   14442,
#   14720,
#   14810,
#   14924,
#   15674,
#   15820,
#   16178,
#   16197,
#   16423,
#   17096,
#   17134,
#   17386,
#   17581,
#   17748,
#   17781,
#   18189,
#   19089,
#   19137,
#   19515,
#   19564,
#   19572,
#   19580,
#   19744,
#   20097,
#   20462,
#   20472,
#   21438,
#   21555,
#   22087,
#   22188,
#   22244,
#   22299,
#   22583,
#   22735,
#   22779,
#   22896,
#   23227,
#   23237,
#   23238,
#   23724,
# ...

# %%
grouped.get_group(('Amer-Indian-Eskimo', 'Female'))
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 212     35            Private  153790   Some-college             10
# 226     60                  ?   24215           10th              6
# 516     25            Private  267044   Some-college             10
# 596     23                  ?   99399   Some-college             10
# 940     31            Private   78602     Assoc-acdm             12
# 1715    39            Private   19914   Some-college             10
# 2036    19                  ?   33487   Some-college             10
# 2313    31          Local-gov  151726     Assoc-acdm             12
# 2383    63            Private   30602        7th-8th              4
# 2610    18            Private   40829           11th              7
# 2720    40          Local-gov   50442   Some-college             10
# 2993    29            Private  100405           10th              6
# 3589    31          Local-gov   50442   Some-college             10
# ...

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                 'B': ['B0', 'B1', 'B2', 'B3'],
                'C': ['C0', 'C1', 'C2', 'C3'],
                'D': ['D0', 'D1', 'D2', 'D3']},
              index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                 'B': ['B4', 'B5', 'B6', 'B7'],
                  'C': ['C4', 'C5', 'C6', 'C7'],
                 'D': ['D4', 'D5', 'D6', 'D7']},
                 index=[4, 5, 6, 7])


df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                  'B': ['B8', 'B9', 'B10', 'B11'],
                 'C': ['C8', 'C9', 'C10', 'C11'],
                 'D': ['D8', 'D9', 'D10', 'D11']},
                index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis = 1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df1.append(df2).append(df3)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                  'key2': ['K0', 'K1', 'K0', 'K1'],
                  'A': ['A0', 'A1', 'A2', 'A3'],
                  'B': ['B0', 'B1', 'B2', 'B3']})





right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                       'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#     A   B key1 key2
# 0  A0  B0   K0   K0
# 1  A1  B1   K0   K1
# 2  A2  B2   K1   K0
# 3  A3  B3   K2   K1

# %%
right
# Out:
#     C   D key1 key2
# 0  C0  D0   K0   K0
# 1  C1  D1   K1   K0
# 2  C2  D2   K1   K0
# 3  C3  D3   K2   K0

# %%
pd.merge(left,right,on = ['key1','key2'],how = "outer")
# Out:
#      A    B key1 key2    C    D
# 0   A0   B0   K0   K0   C0   D0
# 1   A1   B1   K0   K1  NaN  NaN
# 2   A2   B2   K1   K0   C1   D1
# 3   A2   B2   K1   K0   C2   D2
# 4   A3   B3   K2   K1  NaN  NaN
# 5  NaN  NaN   K2   K0   C3   D3

# %%
right1 = right.rename(columns = {"key1":"key_1","key2":"key_2"})

# %%
left
# Out:
#     A   B key1 key2
# 0  A0  B0   K0   K0
# 1  A1  B1   K0   K1
# 2  A2  B2   K1   K0
# 3  A3  B3   K2   K1

# %%
right1
# Out:
#     C   D key_1 key_2
# 0  C0  D0    K0    K0
# 1  C1  D1    K1    K0
# 2  C2  D2    K1    K0
# 3  C3  D3    K2    K0

# %%
pd.merge(left,right1,left_on = ['key1','key2'],right_on = ["key_1","key_2"])
# Out:
#     A   B key1 key2   C   D key_1 key_2
# 0  A0  B0   K0   K0  C0  D0    K0    K0
# 1  A2  B2   K1   K0  C1  D1    K1    K0
# 2  A2  B2   K1   K0  C2  D2    K1    K0

# %%
right2 = right.set_index(['key1','key2'])

# %%
right2
# Out:
#             C   D
# key1 key2
# K0   K0    C0  D0
# K1   K0    C1  D1
#      K0    C2  D2
# K2   K0    C3  D3

# %%
left2 = left.set_index(['key1','key2'])

# %%
pd.merge(left2,right2,left_index = True,right_index=True)
# Out:
#             A   B   C   D
# key1 key2
# K0   K0    A0  B0  C0  D0
# K1   K0    A2  B2  C1  D1
#      K0    A2  B2  C2  D2

# %%
right2
# Out:
#             C   D
# key1 key2
# K0   K0    C0  D0
# K1   K0    C1  D1
#      K0    C2  D2
# K2   K0    C3  D3

# %%
left2
# Out:
#             A   B
# key1 key2
# K0   K0    A0  B0
#      K1    A1  B1
# K1   K0    A2  B2
# K2   K1    A3  B3

# %%
left2.join(right2,how = "inner")
# Out:
#             A   B   C   D
# key1 key2
# K0   K0    A0  B0  C0  D0
# K1   K0    A2  B2  C1  D1
#      K0    A2  B2  C2  D2

# %%
left.join(right2,on = ['key1','key2'],how = "inner")
# Out:
#     A   B key1 key2   C   D
# 0  A0  B0   K0   K0  C0  D0
# 2  A2  B2   K1   K0  C1  D1
# 2  A2  B2   K1   K0  C2  D2

# %%
right2
# Out:
#             C   D
# key1 key2
# K0   K0    C0  D0
# K1   K0    C1  D1
#      K0    C2  D2
# K2   K0    C3  D3
